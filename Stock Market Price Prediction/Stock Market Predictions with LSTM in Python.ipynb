# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'
dataset_train = pd.read_csv(url)
training_set = dataset_train.iloc[:, 1:2].values

# %%
dataset_train.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
dataset_train.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
dataset_train.sample(5)
# Out:
#             Date   Open    High    Low    Last   Close  Total Trade Quantity  \
# 1941  2010-12-01  113.5  116.00  113.0  114.50  114.75                628391
# 2008  2010-08-26  118.2  119.35  116.6  118.00  118.15               2531255
# 555   2016-07-04  135.6  135.80  133.8  134.50  134.10               1144671
# 36    2018-08-03  236.0  239.00  232.0  235.20  234.65               3357945
# 1415  2013-01-09  164.6  164.60  161.5  162.85  162.45               2427569
#
#       Turnover (Lacs)
# 1941           722.87
# 2008          2997.62
# 555           1539.68
# 36            7893.32
# 1415          3961.95

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
dataset_train.count()
# Out:
# Date                    2035
# Open                    2035
# High                    2035
# Low                     2035
# Last                    2035
# Close                   2035
# Total Trade Quantity    2035
# Turnover (Lacs)         2035
# dtype: int64

# %%
dataset_train.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
dataset_train.hist(figsize=(10, 10), layout=(3, 3))
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Last'}>,
#         <Axes: title={'center': 'Close'}>,
#         <Axes: title={'center': 'Total Trade Quantity'}>],
#        [<Axes: title={'center': 'Turnover (Lacs)'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(dataset_train['Open'],label='Open',color='blue')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(dataset_train['Close'],label='Close',color='green')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()
# Out:
# /var/folders/2w/gwk84j355pg3_mwj15__p63m0000gn/T/ipykernel_24913/791730757.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 7s 58ms/step - loss: 0.0096
# Epoch 2/100
# 62/62 [==============================] - 4s 62ms/step - loss: 0.0029
# Epoch 3/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0028
# Epoch 4/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0024
# Epoch 5/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0025
# Epoch 6/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0025
# Epoch 7/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0021
# Epoch 8/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0025
# Epoch 9/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0021
# Epoch 10/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0019
# Epoch 11/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0019
# Epoch 12/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0019
# Epoch 13/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0015
# Epoch 14/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0017
# Epoch 15/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0018
# Epoch 16/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0016
# Epoch 17/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0016
# Epoch 18/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.0016
# Epoch 19/100
# 62/62 [==============================] - 4s 66ms/step - loss: 0.0014
# Epoch 20/100
# 62/62 [==============================] - 4s 66ms/step - loss: 0.0016
# Epoch 21/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0016
# Epoch 22/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0015
# Epoch 23/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0015
# Epoch 24/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0013
# Epoch 25/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0014
# Epoch 26/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0014
# Epoch 27/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0013
# Epoch 28/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0013
# Epoch 29/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0011
# Epoch 30/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0012
# Epoch 31/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0011
# Epoch 32/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0010
# Epoch 33/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0010
# Epoch 34/100
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0011
# Epoch 35/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0013
# Epoch 36/100
# 62/62 [==============================] - 9s 139ms/step - loss: 0.0011
# Epoch 37/100
# 62/62 [==============================] - 7s 107ms/step - loss: 0.0011
# Epoch 38/100
# 62/62 [==============================] - 5s 74ms/step - loss: 9.6005e-04
# Epoch 39/100
# 62/62 [==============================] - 5s 75ms/step - loss: 0.0010
# Epoch 40/100
# 62/62 [==============================] - 4s 66ms/step - loss: 0.0010
# Epoch 41/100
# 62/62 [==============================] - 4s 66ms/step - loss: 9.7691e-04
# Epoch 42/100
# 62/62 [==============================] - 5s 80ms/step - loss: 8.2010e-04
# Epoch 43/100
# 62/62 [==============================] - 4s 66ms/step - loss: 9.0720e-04
# Epoch 44/100
# 62/62 [==============================] - 4s 71ms/step - loss: 8.7014e-04
# Epoch 45/100
# 62/62 [==============================] - 4s 66ms/step - loss: 9.9207e-04
# Epoch 46/100
# 62/62 [==============================] - 4s 65ms/step - loss: 9.6633e-04
# Epoch 47/100
# 62/62 [==============================] - 4s 67ms/step - loss: 9.2214e-04
# Epoch 48/100
# 62/62 [==============================] - 4s 70ms/step - loss: 9.2972e-04
# Epoch 49/100
# 62/62 [==============================] - 6s 94ms/step - loss: 0.0010
# Epoch 50/100
# 62/62 [==============================] - 7s 113ms/step - loss: 9.2204e-04
# Epoch 51/100
# 62/62 [==============================] - 9s 145ms/step - loss: 9.3392e-04
# Epoch 52/100
# 62/62 [==============================] - 5s 81ms/step - loss: 9.8858e-04
# Epoch 53/100
# 62/62 [==============================] - 5s 81ms/step - loss: 9.1194e-04
# Epoch 54/100
# 62/62 [==============================] - 4s 66ms/step - loss: 7.2959e-04
# Epoch 55/100
# 62/62 [==============================] - 4s 65ms/step - loss: 8.6142e-04
# Epoch 56/100
# 62/62 [==============================] - 4s 65ms/step - loss: 8.3233e-04
# Epoch 57/100
# 62/62 [==============================] - 4s 66ms/step - loss: 8.5499e-04
# Epoch 58/100
# 62/62 [==============================] - 4s 65ms/step - loss: 8.2617e-04
# Epoch 59/100
# 62/62 [==============================] - 4s 66ms/step - loss: 7.4358e-04
# Epoch 60/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.8946e-04
# Epoch 61/100
# 62/62 [==============================] - 4s 65ms/step - loss: 8.6109e-04
# Epoch 62/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.5610e-04
# Epoch 63/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.5756e-04
# Epoch 64/100
# 62/62 [==============================] - 4s 65ms/step - loss: 8.3891e-04
# Epoch 65/100
# 62/62 [==============================] - 4s 65ms/step - loss: 8.2430e-04
# Epoch 66/100
# 62/62 [==============================] - 4s 66ms/step - loss: 7.8820e-04
# Epoch 67/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.6809e-04
# Epoch 68/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.4669e-04
# Epoch 69/100
# 62/62 [==============================] - 4s 65ms/step - loss: 8.1578e-04
# Epoch 70/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.8808e-04
# Epoch 71/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.8083e-04
# Epoch 72/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.2905e-04
# Epoch 73/100
# 62/62 [==============================] - 4s 67ms/step - loss: 8.0246e-04
# Epoch 74/100
# 62/62 [==============================] - 5s 77ms/step - loss: 7.1202e-04
# Epoch 75/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.9923e-04
# Epoch 76/100
# 62/62 [==============================] - 4s 66ms/step - loss: 7.3583e-04
# Epoch 77/100
# 62/62 [==============================] - 4s 70ms/step - loss: 6.9739e-04
# Epoch 78/100
# 62/62 [==============================] - 4s 71ms/step - loss: 6.7222e-04
# Epoch 79/100
# 62/62 [==============================] - 4s 68ms/step - loss: 6.6943e-04
# Epoch 80/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.9276e-04
# Epoch 81/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.3470e-04
# Epoch 82/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.7520e-04
# Epoch 83/100
# 62/62 [==============================] - 4s 64ms/step - loss: 6.3923e-04
# Epoch 84/100
# 62/62 [==============================] - 5s 75ms/step - loss: 6.6935e-04
# Epoch 85/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.6904e-04
# Epoch 86/100
# 62/62 [==============================] - 4s 67ms/step - loss: 6.5330e-04
# Epoch 87/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.9775e-04
# Epoch 88/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.3619e-04
# Epoch 89/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.0211e-04
# Epoch 90/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.3442e-04
# Epoch 91/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.9143e-04
# Epoch 92/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.3855e-04
# Epoch 93/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.6853e-04
# Epoch 94/100
# 62/62 [==============================] - 4s 68ms/step - loss: 6.5413e-04
# Epoch 95/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.5317e-04
# Epoch 96/100
# 62/62 [==============================] - 4s 68ms/step - loss: 6.5577e-04
# Epoch 97/100
# 62/62 [==============================] - 5s 76ms/step - loss: 6.1973e-04
# Epoch 98/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.9614e-04
# Epoch 99/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.5509e-04
# Epoch 100/100
# 62/62 [==============================] - 4s 66ms/step - loss: 6.1033e-04

# %%
url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/tatatest.csv'
dataset_test = pd.read_csv(url)
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis=0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1, 1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
plt.plot(real_stock_price, color = 'blue', label = 'Stock Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
